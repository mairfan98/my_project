# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %%
data = pd.read_csv("C:/Users/mdabd/Downloads/UK Gender Pay Gap Data - 2017 to 2018.csv")

# %%
data_new = pd.read_csv("C:/Users/mdabd/Downloads/UK Gender Pay Gap Data - 2018 to 2019.csv")

# %%
data.columns
# Out:
# Index(['EmployerName', 'Address', 'CompanyNumber', 'SicCodes',
#        'DiffMeanHourlyPercent', 'DiffMedianHourlyPercent',
#        'DiffMeanBonusPercent', 'DiffMedianBonusPercent', 'MaleBonusPercent',
#        'FemaleBonusPercent', 'MaleLowerQuartile', 'FemaleLowerQuartile',
#        'MaleLowerMiddleQuartile', 'FemaleLowerMiddleQuartile',
#        'MaleUpperMiddleQuartile', 'FemaleUpperMiddleQuartile',
#        'MaleTopQuartile', 'FemaleTopQuartile', 'CompanyLinkToGPGInfo',
#        'ResponsiblePerson', 'EmployerSize', 'CurrentName',
#        'SubmittedAfterTheDeadline', 'DueDate', 'DateSubmitted'],
#       dtype='object')

# %%
data.shape
# Out:
# (10565, 25)

# %%
data.head()
# Out:
#                            EmployerName  \
# 0       "Bryanston School",Incorporated
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED
# 2                           118 LIMITED
# 3                     123 EMPLOYEES LTD
# 4                          1610 LIMITED
#
#                                              Address CompanyNumber SicCodes  \
# 0       Bryanston House, Blandford, Dorset, DT11 0PX      00226143    85310
# 1   19 Smith's Place, Leith Walk, Edinburgh, EH6 8NU      SC016876    47730
# 2  3 Alexandra Gate Ffordd Pengam, Ground Floor, ...      03951948    61900
# 3          34 Roundhay Road, Leeds, England, LS7 1AB      10530651    78300
# 4  Hestercombe House, Cheddon Fitzpaine, Taunton,...      06727055    93110
#
#    DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# 0                   18.0                     28.2                   0.0
# 1                    2.3                     -2.7                  15.0
# ...

# %%
data_new.columns
# Out:
# Index(['EmployerName', 'Address', 'CompanyNumber', 'SicCodes',
#        'DiffMeanHourlyPercent', 'DiffMedianHourlyPercent',
#        'DiffMeanBonusPercent', 'DiffMedianBonusPercent', 'MaleBonusPercent',
#        'FemaleBonusPercent', 'MaleLowerQuartile', 'FemaleLowerQuartile',
#        'MaleLowerMiddleQuartile', 'FemaleLowerMiddleQuartile',
#        'MaleUpperMiddleQuartile', 'FemaleUpperMiddleQuartile',
#        'MaleTopQuartile', 'FemaleTopQuartile', 'CompanyLinkToGPGInfo',
#        'ResponsiblePerson', 'EmployerSize', 'CurrentName',
#        'SubmittedAfterTheDeadline', 'DueDate', 'DateSubmitted'],
#       dtype='object')

# %%
data_new.shape
# Out:
# (10831, 25)

# %%
data_new.head()
# Out:
#                                         EmployerName  \
# 0  'PRIFYSGOL ABERYSTWYTH' AND 'ABERYSTWYTH UNIVE...
# 1                    "Bryanston School",Incorporated
# 2               "RED BAND" CHEMICAL COMPANY, LIMITED
# 3                                        118 LIMITED
# 4                                  123 EMPLOYEES LTD
#
#                                              Address CompanyNumber SicCodes  \
# 0  Aberystwyth University, Penglais, Ceredigion, ...      RC000641      NaN
# 1       Bryanston House, Blandford, Dorset, DT11 0PX      00226143    85310
# 2   19 Smith's Place, Leith Walk, Edinburgh, EH6 8NU      SC016876    47730
# 3  3 Alexandra Gate Ffordd Pengam, Ground Floor, ...      03951948    61900
# 4          34 Roundhay Road, Leeds, England, LS7 1AB      10530651    78300
#
#    DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# 0                   12.3                      8.4                   NaN
# ...

# %%
data.isnull().sum()
# Out:
# EmployerName                    0
# Address                         0
# CompanyNumber                1359
# SicCodes                      566
# DiffMeanHourlyPercent           0
# DiffMedianHourlyPercent         0
# DiffMeanBonusPercent           24
# DiffMedianBonusPercent         24
# MaleBonusPercent                0
# FemaleBonusPercent              0
# MaleLowerQuartile               0
# FemaleLowerQuartile             0
# MaleLowerMiddleQuartile         0
# FemaleLowerMiddleQuartile       0
# MaleUpperMiddleQuartile         0
# FemaleUpperMiddleQuartile       0
# MaleTopQuartile                 0
# FemaleTopQuartile               0
# CompanyLinkToGPGInfo         2764
# ResponsiblePerson            1677
# EmployerSize                    0
# CurrentName                     0
# SubmittedAfterTheDeadline       0
# DueDate                         0
# DateSubmitted                   0
# dtype: int64

# %%
data_new.isnull().sum()
# Out:
# EmployerName                    0
# Address                         0
# CompanyNumber                1343
# SicCodes                      500
# DiffMeanHourlyPercent           0
# DiffMedianHourlyPercent         0
# DiffMeanBonusPercent         1756
# DiffMedianBonusPercent       1756
# MaleBonusPercent                0
# FemaleBonusPercent              0
# MaleLowerQuartile               0
# FemaleLowerQuartile             0
# MaleLowerMiddleQuartile         0
# FemaleLowerMiddleQuartile       0
# MaleUpperMiddleQuartile         0
# FemaleUpperMiddleQuartile       0
# MaleTopQuartile                 0
# FemaleTopQuartile               0
# CompanyLinkToGPGInfo         3395
# ResponsiblePerson            1692
# EmployerSize                    0
# CurrentName                     0
# SubmittedAfterTheDeadline       0
# DueDate                         0
# DateSubmitted                   0
# dtype: int64

# %%
data["Year"]= "2017-2018"
data.head()
# Out:
#                            EmployerName  \
# 0       "Bryanston School",Incorporated
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED
# 2                           118 LIMITED
# 3                     123 EMPLOYEES LTD
# 4                          1610 LIMITED
#
#                                              Address CompanyNumber SicCodes  \
# 0       Bryanston House, Blandford, Dorset, DT11 0PX      00226143    85310
# 1   19 Smith's Place, Leith Walk, Edinburgh, EH6 8NU      SC016876    47730
# 2  3 Alexandra Gate Ffordd Pengam, Ground Floor, ...      03951948    61900
# 3          34 Roundhay Road, Leeds, England, LS7 1AB      10530651    78300
# 4  Hestercombe House, Cheddon Fitzpaine, Taunton,...      06727055    93110
#
#    DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# 0                   18.0                     28.2                   0.0
# 1                    2.3                     -2.7                  15.0
# ...

# %%
data_new["Year"]= "2018-2019"
data_new.head()
# Out:
#                                         EmployerName  \
# 0  'PRIFYSGOL ABERYSTWYTH' AND 'ABERYSTWYTH UNIVE...
# 1                    "Bryanston School",Incorporated
# 2               "RED BAND" CHEMICAL COMPANY, LIMITED
# 3                                        118 LIMITED
# 4                                  123 EMPLOYEES LTD
#
#                                              Address CompanyNumber SicCodes  \
# 0  Aberystwyth University, Penglais, Ceredigion, ...      RC000641      NaN
# 1       Bryanston House, Blandford, Dorset, DT11 0PX      00226143    85310
# 2   19 Smith's Place, Leith Walk, Edinburgh, EH6 8NU      SC016876    47730
# 3  3 Alexandra Gate Ffordd Pengam, Ground Floor, ...      03951948    61900
# 4          34 Roundhay Road, Leeds, England, LS7 1AB      10530651    78300
#
#    DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# 0                   12.3                      8.4                   NaN
# ...

# %%
final_data = pd.concat([data,data_new])
final_data.head()
# Out:
#                            EmployerName  \
# 0       "Bryanston School",Incorporated
# 1  "RED BAND" CHEMICAL COMPANY, LIMITED
# 2                           118 LIMITED
# 3                     123 EMPLOYEES LTD
# 4                          1610 LIMITED
#
#                                              Address CompanyNumber SicCodes  \
# 0       Bryanston House, Blandford, Dorset, DT11 0PX      00226143    85310
# 1   19 Smith's Place, Leith Walk, Edinburgh, EH6 8NU      SC016876    47730
# 2  3 Alexandra Gate Ffordd Pengam, Ground Floor, ...      03951948    61900
# 3          34 Roundhay Road, Leeds, England, LS7 1AB      10530651    78300
# 4  Hestercombe House, Cheddon Fitzpaine, Taunton,...      06727055    93110
#
#    DiffMeanHourlyPercent  DiffMedianHourlyPercent  DiffMeanBonusPercent  \
# 0                   18.0                     28.2                   0.0
# 1                    2.3                     -2.7                  15.0
# ...

# %%
final_data = final_data.dropna()

# %%
final_data.isnull().sum()
# Out:
# EmployerName                 0
# Address                      0
# CompanyNumber                0
# SicCodes                     0
# DiffMeanHourlyPercent        0
# DiffMedianHourlyPercent      0
# DiffMeanBonusPercent         0
# DiffMedianBonusPercent       0
# MaleBonusPercent             0
# FemaleBonusPercent           0
# MaleLowerQuartile            0
# FemaleLowerQuartile          0
# MaleLowerMiddleQuartile      0
# FemaleLowerMiddleQuartile    0
# MaleUpperMiddleQuartile      0
# FemaleUpperMiddleQuartile    0
# MaleTopQuartile              0
# FemaleTopQuartile            0
# CompanyLinkToGPGInfo         0
# ResponsiblePerson            0
# EmployerSize                 0
# CurrentName                  0
# SubmittedAfterTheDeadline    0
# DueDate                      0
# DateSubmitted                0
# Year                         0
# dtype: int64

# %%
final_data.duplicated().sum()
# Out:
# 0

# %%
final_data.shape
# Out:
# (11088, 26)

# %%
print(os.getcwd())
# Out:
# C:\Users\mdabd

# %%
final_data.to_excel("clean_data.xlsx")
